# %%
import re
import os
import json
import pandas as pd
from typing import Dict, Any

# %%
def sanitize_filename(filename: str) -> str:
    """
    Sanitize the filename by replacing characters that are not allowed in filenames.
    """
    return re.sub(r'[\\/*?:"<>|]', "_", filename)

# %%
def normalize_text(text: str) -> str:
    """
    Normalize text by:
    1. Removing spaced-out characters 
    2. Removing excess spaces
    3. Converting to lowercase
    """
    # Remove spurious character spacing
    text = re.sub(r'(\w)\s+(\w)', r'\1\2', text)

    # Clean up redundant spaces
    return re.sub(r'\s+', ' ', text).strip().lower()

# %%
def extract_attributes(description: str) -> Dict[str, Any]:
    """
    Extract structured attributes from the product description.
    """
    if pd.isna(description) or not description.strip():
        return {}

    description = normalize_text(description)

    attributes = {
        "name": None,
        "brand": None,
        "category": None,
        "color": None,
        "material": [],
        "size": {
            "dimensions": None,
            "length": None,
            "width": None,
            "height": None
        },
        "weight": {"value": None, "unit": None},
        "price": {"currency": None, "value": None, "mrp": None},
        "specifications": {
            "processor": None,
            "ram": None,
            "storage": None,
            "battery": None,
            "display": None,
            "connectivity": []
        },
        "features": [],
        "rating": None,
        "reviews": None,
        "warranty": None
    }

    # Patterns for extraction
    patterns = {
        "color": r"\b(black|white|red|blue|green|yellow|pink|gray|gold|brown|orange|beige|silver)\b",
        "material": r"\b(cotton|leather|plastic|metal|glass|stainless steel|polyester)\b",
        "dimensions": r"(\d+\.?\d*)\s*[x×]\s*(\d+\.?\d*)\s*[x×]\s*(\d+\.?\d*)\s*(cm|inch|inches)",
        "weight": r"(\d+\.?\d*)\s*(kg|g|grams|lbs|pounds)",
        "price": r"(₹|\$|€)?\s*(\d{1,3}(?:,\d{3})*(?:\.\d+)?)",
        "processor": r"(snapdragon|exynos|mediatek|intel core i\d|apple m\d)",
        "ram": r"(\d+)\s*gb\s*ram",
        "storage": r"(\d+)\s*(gb|tb)\s*storage",
        "battery": r"(\d+)\s*mah",
        "display": r"(\d+\.\d+|\d+)\s*(inch|inches|cm)",
        "connectivity": r"(wifi|bluetooth|4g|5g|nfc|usb)",
        "warranty": r"(\d+)\s*(year|month)s?\s*warranty"
    }

    # Extract attributes
    for attr, pattern in patterns.items():
        matches = re.findall(pattern, description, re.IGNORECASE)
        if matches:
            match = matches[0]
            if attr == "dimensions":
                length, width, height, unit = match
                attributes["size"]["dimensions"] = {
                    "length": float(length),
                    "width": float(width),
                    "height": float(height),
                    "unit": unit.lower()
                }
            elif attr == "weight":
                attributes["weight"] = {"value": float(match[0]), "unit": match[1].lower()}
            elif attr == "price":
                currency, value = match
                # Prefer currency if found, otherwise default to '₹'
                attributes["price"] = {
                    "currency": currency.strip() or "₹", 
                    "value": float(value.replace(",", ""))
                }
            elif attr in attributes["specifications"]:
                # Join in case of multiple matches
                attributes["specifications"][attr] = match[0] if isinstance(match, tuple) else match
            elif attr == "connectivity":
                attributes["specifications"]["connectivity"].extend(match if isinstance(match, tuple) else [match])
            elif attr == "color":
                # Get the first color match
                attributes[attr] = match[0] if isinstance(match, tuple) else match
            else:
                attributes[attr] = match[0] if isinstance(match, tuple) else match

    # Features extraction with more flexibility
    features_keywords = ['self-cleaning', 'wireless', 'fast charging', 'bluetooth', 'touchscreen']
    attributes["features"] = [feature for feature in features_keywords if feature in description]

    # Clean attributes by removing empty or null values
    def clean_attributes(attr: Any) -> Any:
        if isinstance(attr, dict):
            return {k: clean_attributes(v) for k, v in attr.items() if v not in [None, {}, [], ""]}
        elif isinstance(attr, list):
            return [clean_attributes(v) for v in attr if v not in [None, {}, [], ""]]
        return attr

    return clean_attributes(attributes)

# %%
def process_json_files_in_folder(input_folder: str, output_folder: str):
    """
    Process each JSON file in a folder, extract attributes, and save the results.
    """
    # Ensure output folder exists
    os.makedirs(output_folder, exist_ok=True)

    for file_name in os.listdir(input_folder):
        if file_name.endswith('.json'):
            input_file_path = os.path.join(input_folder, file_name)

            try:
                with open(input_file_path, 'r', encoding='utf-8') as json_file:
                    data = json.load(json_file)

                product_name = data.get("product_name", "Unnamed Product")
                description = data.get("description", "")

                # Extract attributes
                attributes = extract_attributes(description)
                attributes["product_name"] = product_name

                sanitized_name = sanitize_filename(product_name)
                output_file_path = os.path.join(output_folder, f"{sanitized_name}.json")

                with open(output_file_path, 'w', encoding='utf-8') as output_file:
                    json.dump(attributes, output_file, ensure_ascii=False, indent=4)

                print(f"Processed and saved: {output_file_path}")
            except Exception as e:
                print(f"Error processing {file_name}: {e}")

# %%
# Example usage
input_folder_path = 'json_test_files'  # Update with actual folder path
output_folder_path = 'json_output_results'  # Update with output folder path

# %%
process_json_files_in_folder(input_folder_path, output_folder_path)
# Out:
# Processed and saved: json_output_results\Air Max 270.json
# Processed and saved: json_output_results\Anker PowerCore 20100mAh Portable Charger.json
# Processed and saved: json_output_results\Apple iPad Air (2022).json
# Processed and saved: json_output_results\Aqualens lens cleaner.json
# Processed and saved: json_output_results\Artisan Stand Mixer.json
# Processed and saved: json_output_results\Atomberg SL1 Smart Door Lock.json
# Processed and saved: json_output_results\Baggit Men's Zip Around Wallet.json
# Processed and saved: json_output_results\Bodylovin Vanilla Vibes Body Butter.json
# Processed and saved: json_output_results\Bose QuietComfort 45 Headphones.json
# Processed and saved: json_output_results\Boult 10000 mAh 22.5 W Power Bank.json
# Processed and saved: json_output_results\Breville BES870XL Barista Express Espresso Machine.json
# Processed and saved: json_output_results\Canon EOS R10 Mirrorless Camera Body.json
# Processed and saved: json_output_results\Canon MF272dw Multi-function WiFi Monochrome Laser Printer.json
# Processed and saved: json_output_results\Cherry Blossom Sports Shoe Cleaner.json
# Processed and saved: json_output_results\CMF by Nothing 65 W GaN 3 A 3 Port Mobile Charger.json
# Processed and saved: json_output_results\CMF by Nothing Phone 1.json
# Processed and saved: json_output_results\Colgate Active Salt Toothpaste.json
# Processed and saved: json_output_results\Colin Glass and Surface Cleaner Liquid Spray.json
# Processed and saved: json_output_results\Corner Shelf.json
# Processed and saved: json_output_results\Cotton twill cap.json
# Processed and saved: json_output_results\Cuisinart DCC-3200P1 Perfectemp Coffee Maker.json
# Processed and saved: json_output_results\Deco Window Set of 2 Extendable Curtain Rods.json
# Processed and saved: json_output_results\DELL monitor.json
# Processed and saved: json_output_results\Dell XPS Desktop Computer.json
# Processed and saved: json_output_results\Dennislingo Full Sleeves Slim Fit Shirt.json
# Processed and saved: json_output_results\Dettol Antiseptic Liquid.json
# Processed and saved: json_output_results\Door Curtain.json
# Processed and saved: json_output_results\Eluxe Paris women's boots.json
# Processed and saved: json_output_results\Fitbit Charge 5.json
# Processed and saved: json_output_results\Fitbit Versa 3 Smartwatch.json
# Processed and saved: json_output_results\FKU Micro USB, USB Type C, Lightning OTG Adapter.json
# Processed and saved: json_output_results\Floral Design Chapati Box.json
# Processed and saved: json_output_results\FOGG Men & Women Charm Body Spray.json
# Processed and saved: json_output_results\FUJIFILM X Series X-T4 Mirrorless Camera.json
# Processed and saved: json_output_results\Galaxy S23 Ultra.json
# Processed and saved: json_output_results\Garmin Forerunner 245 Music GPS Running Watch.json
# Processed and saved: json_output_results\Godrej Ezee Liquid Detergent.json
# Processed and saved: json_output_results\Good Knight Gold Flash Liquid Vapourizer (Machine + refill).json
# Processed and saved: json_output_results\Hawkins Wide (HSS3W) Induction Bottom Pressure Cooker.json
# Processed and saved: json_output_results\Head & Shoulders 2-in-1 Smooth and Silky Anti Dandruff Shampoo + Conditioner for Women & Men, With Almond Milk (1 L).json
# Processed and saved: json_output_results\Himalaya Moisturizing Aloe Vera Facewash.json
# Processed and saved: json_output_results\HP Envy x360 Convertible Laptop.json
# Processed and saved: json_output_results\HP Z3700 _Slim form with USB receiver,16 month battery life, 1200DPI Wireless Optical Mouse (2.4GHz Wireless, Silver).json
# Processed and saved: json_output_results\IFB 1.5 Ton 3 Star Hot and Cold Split Inverter AC.json
# Processed and saved: json_output_results\Instant Pot Duo 7-in-1 Electric Pressure Cooker.json
# Processed and saved: json_output_results\iPhone 14 Pro.json
# Processed and saved: json_output_results\Jockey striped women night shorts.json
# Processed and saved: json_output_results\LG Full HD LED Smart TV.json
# Processed and saved: json_output_results\LG OLED55CXPUA Alexa Built-In OLED TV.json
# Processed and saved: json_output_results\Lifebuoy Soap - Pack of 4.json
# Processed and saved: json_output_results\Logitech MX Master 3 Wireless Mouse.json
# Processed and saved: json_output_results\MacBook AIR Apple M2.json
# Processed and saved: json_output_results\Michael Kors Women Hand-held Bag.json
# Processed and saved: json_output_results\Miele Complete C3 Vacuum Cleaner_.json
# Processed and saved: json_output_results\Mini Air Cooler with 7 Colors LED Light USB Air Cooler (Multicolor).json
# Processed and saved: json_output_results\Motorola G85 5G.json
# Processed and saved: json_output_results\MountMiller cargo Pant.json
# Processed and saved: json_output_results\Nespresso VertuoPlus Coffee Maker.json
# Processed and saved: json_output_results\Nihar Naturals coconut with methi jasmine hair oil.json
# Processed and saved: json_output_results\NIVEA MEN Deodrant.json
# Processed and saved: json_output_results\Nycil Cool Herbal Powder.json
# Processed and saved: json_output_results\Odonil Room Air Freshener Spray.json
# Processed and saved: json_output_results\Origami 2 Ply Tissue Paper Napkins.json
# Processed and saved: json_output_results\OXO Good Grips Salad Spinner.json
# Processed and saved: json_output_results\Panasonic Lumix G85 Mirrorless Camera.json
# Processed and saved: json_output_results\Philips Hue White and Color Ambiance LED Smart Bulb.json
# Processed and saved: json_output_results\Portronics Key7 Combo Mouse Combo Set.json
# Processed and saved: json_output_results\Portronics Radian Soundbar.json
# Processed and saved: json_output_results\Razer DeathAdder V2 Gaming Mouse.json
# Processed and saved: json_output_results\Redmi Note 11 PRO Plus 5G.json
# Processed and saved: json_output_results\Relaxed Fit Trousers.json
# Processed and saved: json_output_results\Safari Medium Check-in Suitcase.json
# Processed and saved: json_output_results\Samsung Galaxy Book4 Intel Core i7 13th Gen.json
# Processed and saved: json_output_results\SAMSUNG Galaxy S23 FE.json
# Processed and saved: json_output_results\Samsung Galaxy S24.json
# Processed and saved: json_output_results\Samsung Galaxy Tab S7 Tablet.json
# Processed and saved: json_output_results\Sensodyne Mouthwash.json
# Processed and saved: json_output_results\Silver-Plated Trellis Metal Photo Frame.json
# Processed and saved: json_output_results\Slovic Dumbbells Set.json
# Processed and saved: json_output_results\Solid Wood Dressing Table.json
# Processed and saved: json_output_results\Sony PlayStation 5 Console.json
# Processed and saved: json_output_results\Sony PS5 DualSense Wireless Controller.json
# Processed and saved: json_output_results\Stainless Steel Coffee Mug.json
# Processed and saved: json_output_results\Surf Excel Easy Wash Detergent Powder.json
# Processed and saved: json_output_results\Tefal Ingenio Non-Stick Cookware Set.json
# Processed and saved: json_output_results\Thin and Light Laptop.json
# Processed and saved: json_output_results\UrbanGabru Frozt Hair Setting Spray.json
# Processed and saved: json_output_results\Volini Activ Spray.json
# Processed and saved: json_output_results\Wakefit Memory Foam Solid Sleeping Pillow.json
# Processed and saved: json_output_results\WD WD GREEN WDS240G3G0A SSD.json
# Processed and saved: json_output_results\WH-1000XM5 Headphones.json
# Processed and saved: json_output_results\Women Bralette Lightly Padded Bra.json
# Processed and saved: json_output_results\Women Embellished Round-Neck Kaftan.json
# Processed and saved: json_output_results\Women Slim Belt with Push Pin Closure.json
# Processed and saved: json_output_results\Wood Single Bed.json
# Processed and saved: json_output_results\XPS 13 Laptop.json
# Processed and saved: json_output_results\Zebronics Power Bank.json
# Processed and saved: json_output_results\Zovilstore analog silver clock.json
# Processed and saved: json_output_results\_ EOS Rebel T7 DSLR Camera.json
